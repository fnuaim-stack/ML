# %% [markdown]
# # Using Jupyter Notebooks
# :label:`sec_jupyter`
#
#
# This section describes how to edit and run the code
# in each section of this book
# using the Jupyter Notebook. Make sure you have
# installed Jupyter and downloaded the
# code as described in
# :ref:`chap_installation`.
# If you want to know more about Jupyter see the excellent tutorial in
# their [documentation](https://jupyter.readthedocs.io/en/latest/).
#
#
# ## Editing and Running the Code Locally
#
# Suppose that the local path of the book's code is `xx/yy/d2l-en/`. Use the shell to change the directory to this path (`cd xx/yy/d2l-en`) and run the command `jupyter notebook`. If your browser does not do this automatically, open http://localhost:8888 and you will see the interface of Jupyter and all the folders containing the code of the book, as shown in :numref:`fig_jupyter00`.
#
# ![The folders containing the code of this book.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter00.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter00`
#
#
# You can access the notebook files by clicking on the folder displayed on the webpage.
# They usually have the suffix ".ipynb".
# For the sake of brevity, we create a temporary "test.ipynb" file.
# The content displayed after you click it is
# shown in :numref:`fig_jupyter01`.
# This notebook includes a markdown cell and a code cell. The content in the markdown cell includes "This Is a Title" and "This is text.".
# The code cell contains two lines of Python code.
#
# ![Markdown and code cells in the "text.ipynb" file.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter01.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter01`
#
#
# Double click on the markdown cell to enter edit mode.
# Add a new text string "Hello world." at the end of the cell, as shown in :numref:`fig_jupyter02`.
#
# ![Edit the markdown cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter02.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter02`
#
#
# As demonstrated in :numref:`fig_jupyter03`,
# click "Cell" $\rightarrow$ "Run Cells" in the menu bar to run the edited cell.
#
# ![Run the cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter03.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter03`
#
# After running, the markdown cell is shown in :numref:`fig_jupyter04`.
#
# ![The markdown cell after running.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter04.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter04`
#
#
# Next, click on the code cell. Multiply the elements by 2 after the last line of code, as shown in :numref:`fig_jupyter05`.
#
# ![Edit the code cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter05.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter05`
#
#
# You can also run the cell with a shortcut ("Ctrl + Enter" by default) and obtain the output result from :numref:`fig_jupyter06`.
#
# ![Run the code cell to obtain the output.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter06.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter06`
#
#
# When a notebook contains more cells, we can click "Kernel" $\rightarrow$ "Restart & Run All" in the menu bar to run all the cells in the entire notebook. By clicking "Help" $\rightarrow$ "Edit Keyboard Shortcuts" in the menu bar, you can edit the shortcuts according to your preferences.
#
# ## Advanced Options
#
# Beyond local editing two things are quite important: editing the notebooks in the markdown format and running Jupyter remotely.
# The latter matters when we want to run the code on a faster server.
# The former matters since Jupyter's native ipynb format stores a lot of auxiliary data that is
# irrelevant to the content,
# mostly related to how and where the code is run.
# This is confusing for Git, making
# reviewing contributions very difficult.
# Fortunately there is an alternative---native editing in the markdown format.
#
# ### Markdown Files in Jupyter
#
# If you wish to contribute to the content of this book, you need to modify the
# source file (md file, not ipynb file) on GitHub.
# Using the notedown plugin we
# can modify notebooks in the md format directly in Jupyter.
#
#
# First, install the notedown plugin, run the Jupyter Notebook, and load the plugin:
#
# ```
# pip install d2l-notedown  # You may need to uninstall the original notedown.
# jupyter notebook --NotebookApp.contents_manager_class='notedown.NotedownContentsManager'
# ```
#
# You may also turn on the notedown plugin by default whenever you run the Jupyter Notebook.
# First, generate a Jupyter Notebook configuration file (if it has already been generated, you can skip this step).
#
# ```
# jupyter notebook --generate-config
# ```
#
# Then, add the following line to the end of the Jupyter Notebook configuration file (for Linux or macOS, usually in the path `~/.jupyter/jupyter_notebook_config.py`):
#
# ```
# c.NotebookApp.contents_manager_class = 'notedown.NotedownContentsManager'
# ```
#
# After that, you only need to run the `jupyter notebook` command to turn on the notedown plugin by default.
#
# ### Running Jupyter Notebooks on a Remote Server
#
# Sometimes, you may want to run Jupyter notebooks on a remote server and access it through a browser on your local computer. If Linux or macOS is installed on your local machine (Windows can also support this function through third-party software such as PuTTY), you can use port forwarding:
#
# ```
# ssh myserver -L 8888:localhost:8888
# ```
#
# The above string `myserver` is the address of the remote server.
# Then we can use http://localhost:8888 to access the remote server `myserver` that runs Jupyter notebooks. We will detail on how to run Jupyter notebooks on AWS instances
# later in this appendix.
#
# ### Timing
#
# We can use the `ExecuteTime` plugin to time the execution of each code cell in Jupyter notebooks.
# Use the following commands to install the plugin:
#
# ```
# pip install jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user
# jupyter nbextension enable execute_time/ExecuteTime
# ```
#
# ## Summary
#
# * Using the Jupyter Notebook tool, we can edit, run, and contribute to each section of the book.
# * We can run Jupyter notebooks on remote servers using port forwarding.
#
#
# ## Exercises
#
# 1. Edit and run the code in this book with the Jupyter Notebook on your local machine.
# 1. Edit and run the code in this book with the Jupyter Notebook *remotely* via port forwarding.
# 1. Compare the running time of the operations $\mathbf{A}^\top \mathbf{B}$ and $\mathbf{A} \mathbf{B}$ for two square matrices in $\mathbb{R}^{1024 \times 1024}$. Which one is faster?
#
#
# [Discussions](https://discuss.d2l.ai/t/421)

# %%
plt.figure()
plt.scatter(principal_components[:,0], principal_components[:,1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Projection")
plt.show()

# %%
X = df_zscore[numeric_cols]

pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)

print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.23527786 0.20811531]

# %%
scaler_std = StandardScaler()

df_zscore = df_no_outliers.copy()
df_zscore[numeric_cols] = scaler_std.fit_transform(df_no_outliers[numeric_cols])

df_zscore.head()
# Out:
#      Car_ID     Brand  Manufacture_Year  Body_Type Fuel_Type Transmission  \
# 0  CAR_0001  Mercedes         -1.531770        SUV    Petrol       Manual
# 1  CAR_0002    Nissan          1.322460      Coupe    Petrol    Automatic
# 2  CAR_0003    Nissan         -1.363874  Hatchback    Diesel       Manual
# 3  CAR_0004    Nissan         -0.356499      Coupe    Petrol       Manual
# 4  CAR_0005   Hyundai         -1.028083  Hatchback    Hybrid    Automatic
#
#    Engine_CC  Horsepower  Mileage_km_per_l  Price_USD Manufacturing_Country
# 0   0.928362    1.429601         -0.451423   0.365190                   USA
# 1   1.402346   -1.054918          0.877921   0.538593                   USA
# 2  -1.120787   -1.427596         -0.617591   0.456559                 China
# 3  -1.091219    0.291953         -0.617591  -0.352646                   USA
# 4  -0.645908   -1.198759          1.376425   0.651859                    UK

# %%
scaler_minmax = MinMaxScaler()

df_minmax = df_no_outliers.copy()
df_minmax[numeric_cols] = scaler_minmax.fit_transform(df_no_outliers[numeric_cols])

df_minmax.head()
# Out:
#      Car_ID     Brand  Manufacture_Year  Body_Type Fuel_Type Transmission  \
# 0  CAR_0001  Mercedes              0.05        SUV    Petrol       Manual
# 1  CAR_0002    Nissan              0.90      Coupe    Petrol    Automatic
# 2  CAR_0003    Nissan              0.10  Hatchback    Diesel       Manual
# 3  CAR_0004    Nissan              0.40      Coupe    Petrol       Manual
# 4  CAR_0005   Hyundai              0.20  Hatchback    Hybrid    Automatic
#
#    Engine_CC  Horsepower  Mileage_km_per_l  Price_USD Manufacturing_Country
# 0   0.773353    0.901701              0.35   0.596209                   USA
# 1   0.905835    0.183365              0.75   0.648348                   USA
# 2   0.200601    0.075614              0.30   0.623682                 China
# 3   0.208866    0.572779              0.30   0.380367                   USA
# 4   0.333333    0.141777              0.90   0.682406                    UK

# %%
numeric_cols = df_no_outliers.select_dtypes(include=np.number).columns

# %%
plt.figure()
sns.boxplot(x=df_no_outliers[col])
plt.title("After Removing Outliers")
plt.show()

# %%
plt.figure()
sns.boxplot(x=df[col])
plt.title("Before Removing Outliers")
plt.show()

# %%
df_no_outliers = df[(df[col] >= lower) & (df[col] <= upper)]

print("Original shape:", df.shape)
print("After removing outliers:", df_no_outliers.shape)
# Out:
# Original shape: (300, 11)
# After removing outliers: (300, 11)

# %%
col = "Price_USD"   # change if needed

Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df[col] < lower) | (df[col] > upper)]

print("Number of outliers:", len(outliers))
# Out:
# Number of outliers: 0

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:
    df[col].fillna(df[col].median(), inplace=True)

df.isnull().sum()
# Out:
# /tmp/ipykernel_998/1034381409.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# Car_ID                   0
# Brand                    0
# Manufacture_Year         0
# Body_Type                0
# Fuel_Type                0
# Transmission             0
# Engine_CC                0
# Horsepower               0
# Mileage_km_per_l         0
# Price_USD                0
# Manufacturing_Country    0
# dtype: int64

# %% [markdown]
# ### Basic Data Exploration
#
# Let's get an initial understanding of the dataset by checking its structure, summary statistics, and missing values.

# %%
print('--- DataFrame Info ---')
df.info()
# Out:
# --- DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Car_ID                 300 non-null    object
#  1   Brand                  300 non-null    object
#  2   Manufacture_Year       300 non-null    int64
#  3   Body_Type              300 non-null    object
#  4   Fuel_Type              300 non-null    object
#  5   Transmission           300 non-null    object
#  6   Engine_CC              300 non-null    int64
#  7   Horsepower             300 non-null    int64
#  8   Mileage_km_per_l       300 non-null    int64
#  9   Price_USD              300 non-null    int64
#  10  Manufacturing_Country  300 non-null    object
# dtypes: int64(5), object(6)
# memory usage: 25.9+ KB

# %%
print('\n--- Descriptive Statistics ---')
display(df.describe())
# Out:
# --- Descriptive Statistics ---
#        Manufacture_Year    Engine_CC  Horsepower  Mileage_km_per_l  \
# count        300.000000   300.000000  300.000000        300.000000
# mean        2015.123333  3052.880000  328.346667         19.716667
# std            5.966023  1117.937497  153.202644          6.028061
# min         2005.000000  1001.000000   70.000000         10.000000
# 25%         2010.000000  2074.000000  188.250000         15.000000
# 50%         2015.000000  3117.500000  329.500000         19.500000
# 75%         2020.000000  3964.000000  454.750000         24.000000
# max         2025.000000  4994.000000  599.000000         30.000000
#
#            Price_USD
# count     300.000000
# mean    60848.823333
# std     34445.525598
# min      5221.000000
# 25%     29418.500000
# 50%     59179.500000
# 75%     89692.250000
# max    119587.000000

# %%
print('\n--- Missing Values Summary ---')
display(df.isnull().sum().to_frame(name='Missing Count'))
# Out:
# --- Missing Values Summary ---
#                        Missing Count
# Car_ID                             0
# Brand                              0
# Manufacture_Year                   0
# Body_Type                          0
# Fuel_Type                          0
# Transmission                       0
# Engine_CC                          0
# Horsepower                         0
# Mileage_km_per_l                   0
# Price_USD                          0
# Manufacturing_Country              0

# %%
df = pd.read_csv("global_cars_dataset_synthetic (1).csv")

df.head()
# Out:
#      Car_ID     Brand  Manufacture_Year  Body_Type Fuel_Type Transmission  \
# 0  CAR_0001  Mercedes              2006        SUV    Petrol       Manual
# 1  CAR_0002    Nissan              2023      Coupe    Petrol    Automatic
# 2  CAR_0003    Nissan              2007  Hatchback    Diesel       Manual
# 3  CAR_0004    Nissan              2013      Coupe    Petrol       Manual
# 4  CAR_0005   Hyundai              2009  Hatchback    Hybrid    Automatic
#
#    Engine_CC  Horsepower  Mileage_km_per_l  Price_USD Manufacturing_Country
# 0       4089         547                17      73407                   USA
# 1       4618         167                25      79370                   USA
# 2       1802         110                16      76549                 China
# 3       1835         373                16      48722                   USA
# 4       2332         145                28      83265                    UK

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA

sns.set_style("whitegrid")

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('/content/global_cars_dataset_synthetic (1).csv')

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#      Car_ID     Brand  Manufacture_Year  Body_Type Fuel_Type Transmission  \
# 0  CAR_0001  Mercedes              2006        SUV    Petrol       Manual
# 1  CAR_0002    Nissan              2023      Coupe    Petrol    Automatic
# 2  CAR_0003    Nissan              2007  Hatchback    Diesel       Manual
# 3  CAR_0004    Nissan              2013      Coupe    Petrol       Manual
# 4  CAR_0005   Hyundai              2009  Hatchback    Hybrid    Automatic
#
#    Engine_CC  Horsepower  Mileage_km_per_l  Price_USD Manufacturing_Country
# 0       4089         547                17      73407                   USA
# 1       4618         167                25      79370                   USA
# 2       1802         110                16      76549                 China
# 3       1835         373                16      48722                   USA
# 4       2332         145                28      83265                    UK

# %% [markdown]
# # Task
# Perform data preprocessing and dimensionality reduction on the "global_cars_dataset_synthetic (1).csv" dataset. This involves: loading the data, performing basic exploration, imputing missing numeric values with the median, detecting and removing outliers from the "Price_USD" column (visualizing its distribution before and after removal), scaling numeric features using both Min-Max scaling and Standard scaling, and finally applying PCA with 2 components to the standardized data. Visualize the PCA projection and summarize the entire process and its findings.

# %% [markdown]
# ## Visualize Price Distribution Before Outlier Removal
#
# ### Subtask:
# Generate a box plot for the 'Price_USD' column to visualize its distribution and the presence of outliers before removal.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of 'Price_USD' and identify outliers before removal, I will create a box plot using seaborn and display it.

# %%
plt.figure()
sns.boxplot(x=df[col])
plt.title("Before Removing Outliers")
plt.show()

# %% [markdown]
# ## Remove Outliers from Price_USD
#
# ### Subtask:
# Create a new DataFrame `df_no_outliers` by filtering out the identified outliers from the 'Price_USD' column. Print the original and new DataFrame shapes for comparison.

# %% [markdown]
# **Reasoning**:
# To remove outliers from the 'Price_USD' column, I will create a new DataFrame `df_no_outliers` by filtering the original DataFrame `df` based on the calculated lower and upper bounds. Then, I will print the shapes of both DataFrames to show the effect of outlier removal.

# %%
df_no_outliers = df[(df[col] >= lower) & (df[col] <= upper)]

print("Original shape:", df.shape)
print("After removing outliers:", df_no_outliers.shape)
# Out:
# Original shape: (300, 11)
# After removing outliers: (300, 11)

# %% [markdown]
# ## Visualize Price Distribution After Outlier Removal
#
# ### Subtask:
# Generate a box plot for the 'Price_USD' column from the `df_no_outliers` DataFrame to visualize its distribution after outlier removal. Provide a clear title for the plot.

# %% [markdown]
# **Reasoning**:
# To visualize the distribution of 'Price_USD' after removing outliers, I will create a box plot using seaborn, setting an appropriate title, and then display the plot.

# %%
plt.figure()
sns.boxplot(x=df_no_outliers[col])
plt.title("After Removing Outliers")
plt.show()

# %% [markdown]
# **Reasoning**:
# Now that outliers have been removed, the next step is to identify all numeric columns in the `df_no_outliers` DataFrame. This list of columns will be used for subsequent scaling and dimensionality reduction operations, ensuring that only numerical features are processed.

# %%
numeric_cols = df_no_outliers.select_dtypes(include=np.number).columns
print("Numeric columns identified:", numeric_cols.tolist())
# Out:
# Numeric columns identified: ['Manufacture_Year', 'Engine_CC', 'Horsepower', 'Mileage_km_per_l', 'Price_USD']

# %% [markdown]
# ## Min-Max Scaling
#
# ### Subtask:
# Apply `MinMaxScaler` to the numeric columns of `df_no_outliers` to scale values between 0 and 1. Store the result in `df_minmax` and display its head.

# %% [markdown]
# **Reasoning**:
# To apply Min-Max scaling, I will first instantiate the `MinMaxScaler`, then create a copy of the `df_no_outliers` DataFrame, and finally apply the scaler's `fit_transform` method to the identified numeric columns before displaying the head of the resulting `df_minmax` DataFrame.

# %%
scaler_minmax = MinMaxScaler()

df_minmax = df_no_outliers.copy()
df_minmax[numeric_cols] = scaler_minmax.fit_transform(df_no_outliers[numeric_cols])

df_minmax.head()
# Out:
#      Car_ID     Brand  Manufacture_Year  Body_Type Fuel_Type Transmission  \
# 0  CAR_0001  Mercedes              0.05        SUV    Petrol       Manual
# 1  CAR_0002    Nissan              0.90      Coupe    Petrol    Automatic
# 2  CAR_0003    Nissan              0.10  Hatchback    Diesel       Manual
# 3  CAR_0004    Nissan              0.40      Coupe    Petrol       Manual
# 4  CAR_0005   Hyundai              0.20  Hatchback    Hybrid    Automatic
#
#    Engine_CC  Horsepower  Mileage_km_per_l  Price_USD Manufacturing_Country
# 0   0.773353    0.901701              0.35   0.596209                   USA
# 1   0.905835    0.183365              0.75   0.648348                   USA
# 2   0.200601    0.075614              0.30   0.623682                 China
# 3   0.208866    0.572779              0.30   0.380367                   USA
# 4   0.333333    0.141777              0.90   0.682406                    UK

# %% [markdown]
# ## Standard Scaling
#
# ### Subtask:
# Apply `StandardScaler` to the numeric columns of `df_no_outliers` to standardize the data. Store the result in `df_zscore` and display its head.

# %% [markdown]
# ## Standard Scaling
#
# ### Subtask:
# Apply `StandardScaler` to the numeric columns of `df_no_outliers` to standardize the data. Store the result in `df_zscore` and display its head.

# %% [markdown]
# #### Instructions
# 1. Instantiate a `StandardScaler` object.
# 2. Create a copy of `df_no_outliers` and assign it to `df_zscore`.
# 3. Apply the `StandardScaler` to the `numeric_cols` of `df_zscore` using `fit_transform()` and update the respective columns in `df_zscore`.
# 4. Display the first few rows of the `df_zscore` DataFrame using `.head()` to verify the scaling.

# %% [markdown]
# #### Instructions
# 1. Instantiate a `StandardScaler` object.
# 2. Create a copy of `df_no_outliers` and assign it to `df_zscore`.
# 3. Apply the `StandardScaler` to the `numeric_cols` of `df_zscore` using `fit_transform()` and update the respective columns in `df_zscore`.
# 4. Display the first few rows of the `df_zscore` DataFrame using `.head()` to verify the scaling.

# %% [markdown]
# **Reasoning**:
# Following the instructions for Standard Scaling, I will now implement the code to instantiate `StandardScaler`, create a copy of `df_no_outliers`, apply the scaling to the numeric columns, and display the head of the resulting `df_zscore` DataFrame.

# %%
scaler_std = StandardScaler()

df_zscore = df_no_outliers.copy()
df_zscore[numeric_cols] = scaler_std.fit_transform(df_no_outliers[numeric_cols])

df_zscore.head()
# Out:
#      Car_ID     Brand  Manufacture_Year  Body_Type Fuel_Type Transmission  \
# 0  CAR_0001  Mercedes         -1.531770        SUV    Petrol       Manual
# 1  CAR_0002    Nissan          1.322460      Coupe    Petrol    Automatic
# 2  CAR_0003    Nissan         -1.363874  Hatchback    Diesel       Manual
# 3  CAR_0004    Nissan         -0.356499      Coupe    Petrol       Manual
# 4  CAR_0005   Hyundai         -1.028083  Hatchback    Hybrid    Automatic
#
#    Engine_CC  Horsepower  Mileage_km_per_l  Price_USD Manufacturing_Country
# 0   0.928362    1.429601         -0.451423   0.365190                   USA
# 1   1.402346   -1.054918          0.877921   0.538593                   USA
# 2  -1.120787   -1.427596         -0.617591   0.456559                 China
# 3  -1.091219    0.291953         -0.617591  -0.352646                   USA
# 4  -0.645908   -1.198759          1.376425   0.651859                    UK

# %% [markdown]
# ## Apply PCA
#
# ### Subtask:
# Apply PCA with 2 components to the `df_zscore` (standardized) DataFrame. Store the transformed data in `principal_components` and print the explained variance ratio.

# %% [markdown]
# #### Instructions
# 1. Select the numeric columns from `df_zscore` for PCA.
# 2. Instantiate a `PCA` object with `n_components=2`.
# 3. Apply `fit_transform()` to the selected numeric columns from `df_zscore` and store the result in `principal_components`.
# 4. Print the `explained_variance_ratio_` of the PCA model to understand the variance captured by the two components.

# %% [markdown]
# #### Instructions
# 1. Select the numeric columns from `df_zscore` for PCA.
# 2. Instantiate a `PCA` object with `n_components=2`.
# 3. Apply `fit_transform()` to the selected numeric columns from `df_zscore` and store the result in `principal_components`.
# 4. Print the `explained_variance_ratio_` of the PCA model to understand the variance captured by the two components.

# %% [markdown]
# **Reasoning**:
# Following the instructions, I will now implement the PCA application. This involves selecting the numeric columns from the `df_zscore` DataFrame, initializing a PCA model with 2 components, transforming the selected data, and finally printing the explained variance ratio to assess the dimensionality reduction.

# %%
X = df_zscore[numeric_cols]

pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)

print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.23527786 0.20811531]

# %% [markdown]
# ## Visualize PCA Projection
#
# ### Subtask:
# Create a scatter plot of the two principal components to visualize the PCA projection. Label the axes as 'PC1' and 'PC2' and provide a title for the plot.

# %% [markdown]
# #### Instructions
# 1. Create a figure using `plt.figure()`.
# 2. Generate a scatter plot using `plt.scatter()`, passing the first principal component (`principal_components[:,0]`) for the x-axis and the second principal component (`principal_components[:,1]`) for the y-axis.
# 3. Label the x-axis as 'PC1' using `plt.xlabel()`.
# 4. Label the y-axis as 'PC2' using `plt.ylabel()`.
# 5. Add a title to the plot, such as 'PCA Projection', using `plt.title()`.
# 6. Display the plot using `plt.show()`.

# %% [markdown]
# **Reasoning**:
# Now, I will implement the code to visualize the PCA projection using a scatter plot, following the provided instructions. This will display the first two principal components, with appropriate labels and title, to graphically represent the dimensionality reduction.

# %%
plt.figure()
plt.scatter(principal_components[:,0], principal_components[:,1])
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Projection")
plt.show()
